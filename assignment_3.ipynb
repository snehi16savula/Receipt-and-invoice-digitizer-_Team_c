# %% [markdown]
# <a href="https://colab.research.google.com/github/snehi16savula/Receipt-and-invoice-digitizer-_Team_c/blob/main/assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x =10

y = "Hello"

z= [1, 2, 3]

print(isinstance(x, int))
# Out:
# True

# %%
print(isinstance(y, str))
# Out:
# True

# %%
print(isinstance(z, list))
# Out:
# True

# %%
print(isinstance(z, tuple))
# Out:
# False

# %%
#Example: Using isinstance()

x = 10

y = "Hello"

z = [1, 2, 3]

print(isinstance(x, int))
# Out:
# True

# %%
print(isinstance(y, str))
# Out:
# True

# %%
print(isinstance(z, list))
# Out:
# True

# %%
print(isinstance(z, tuple))
# Out:
# False

# %%
#3 question
import gc

class Demo:
    def __del__(self):
        print("Object destroyed")

# Create object
obj = Demo()

# Delete reference
del obj

# Manually call garbage collector
gc.collect()

print("Program Ended")
# Out:
# Object destroyed
# Program Ended

# %% [markdown]
# # New Section
